# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 데이터 불러오기
train_data = pd.read_csv('./data/ratings_train.csv', encoding = 'cp949')
test_data = pd.read_csv('./data/ratings_test.csv', encoding = 'cp949')

# %%
print(train_data)
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 3 columns]

# %%
print(train_data['label'].value_counts())
print(test_data['label'].value_counts())

# 두 경우 다 긍정, 부정 비율이 50% 정도임
# Out:
# 0    75173
# 1    74827
# Name: label, dtype: int64
# 1    25173
# 0    24827
# Name: label, dtype: int64

# %% [markdown]
# ## 데이터 전처리
#
# 토큰화, 불용어 처리, 어간 추출, 벡터화 순으로

# %%
print(train_data['document'].nunique(), train_data['label'].nunique())
# Out:
# 146157 2

# %%
train_data.drop_duplicates(subset=['document'], inplace=True)
test_data.drop_duplicates(subset=['document'], inplace=True)

# %%
# 리뷰 중 널값 확인

print(train_data.isnull().values.any())
# Out:
# True

# %%
# 널값 위치 확인 

print(train_data.isnull().sum())
# Out:
# id          0
# document    1
# label       0
# dtype: int64

# %%
print(test_data.isnull().sum())
# Out:
# id          0
# document    1
# label       0
# dtype: int64

# %%
train_data.loc[train_data.document.isnull()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
test_data.loc[test_data.document.isnull()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
train_data = train_data.dropna(how = 'any') # Null 값이 존재하는 행 제거
test_data = test_data.dropna(how = 'any')

# %%
# 정규표현식으로 한글과 공백을 제외한 모든 문자 제거

train_data['document'] = train_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')
test_data['document'] = test_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')
# Out:
# C:\Users\wpghf\AppData\Local\Temp/ipykernel_23740/2221766604.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')
# C:\Users\wpghf\AppData\Local\Temp/ipykernel_23740/2221766604.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')

# %%
train_data[:5]
# Out:
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
# 한글과 공백 빼고 모두 제거했기에, null값을 다시 확인한다.

train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
train_data['document'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# id            0
# document    784
# label         0
# dtype: int64
# C:\Users\wpghf\AppData\Local\Temp/ipykernel_23740/2482942070.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경

# %%
test_data['document'] = test_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
test_data['document'].replace('', np.nan, inplace=True)
print(test_data.isnull().sum())
# Out:
# id            0
# document    303
# label         0
# dtype: int64
# C:\Users\wpghf\AppData\Local\Temp/ipykernel_23740/1307184367.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경

# %%
# 다시 널값 제거
train_data = train_data.dropna(how = 'any')
test_data = test_data.dropna(how = 'any')

# %% [markdown]
# ## 토큰화

# %%
# 불용어 리스트 만들기
a = pd.read_csv('./data/stopwords.csv', encoding = 'cp949')
stopwords = []
for i in range(0, 677):
    stopwords.append(a['stopwords'][i])
    
stopwords
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
# ...

# %%
okt = Okt()
okt.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔', stem = True)
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23740/688417519.py in <module>
# ----> 1 okt = Okt()
#       2 okt.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔', stem = True)
#
# ~\anaconda3\lib\site-packages\konlpy\tag\_okt.py in __init__(self, jvmpath, max_heap_size)
#      49     def __init__(self, jvmpath=None, max_heap_size=1024):
#      50         if not jpype.isJVMStarted():
# ---> 51             jvm.init_jvm(jvmpath, max_heap_size)
#      52
#      53         oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#
# ~\anaconda3\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      53     classpath = [f.format(*args) for f in folder_suffix]
#      54
# ---> 55     jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      56
#      57     # NOTE: Temporary patch for Issue #76. Erase when possible.
#
# ...

# %%
# !pip install --upgrade pip
# !pip install JPype1-0.5.7-cp10-none-win_amd64.whl
# Out:
# ...
# WARNING: Requirement 'JPype1-0.5.7-cp10-none-win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: JPype1-0.5.7-cp10-none-win_amd64.whl is not a supported wheel on this platform.

# %% [markdown]
# # LSTM으로 영화 리뷰 감성 분류
#
# 출철 : https://wikidocs.net/44249

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 코드 돌리기 전에 vocab_size 설정 해야함


embedding_dim = 100
hidden_units = 128


model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))



es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)



model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))

# %%
# 리뷰 예측하기

def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %% [markdown]
# #
